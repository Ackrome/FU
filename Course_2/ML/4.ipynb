# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
import time as dt


x = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/main/ML1.2%20multivariate/data/0_x.csv",header=None)
y = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/main/ML1.2%20multivariate/data/0_y.csv",header=None)
x
# Out:
#             0         1         2         3         4
# 0    0.071841  0.855352 -0.305597  0.028253  1.826895
# 1    0.139521 -0.423507  0.461059 -0.447400 -0.034988
# 2    1.626311 -0.257622 -0.697520  1.413219  1.086292
# 3   -1.183233 -0.826343  0.073047 -0.639690 -0.503273
# 4   -0.783365 -0.861232  0.951448 -0.117306  0.680597
# ..        ...       ...       ...       ...       ...
# 382  0.684004  2.320728  0.380965 -1.050408 -0.151801
# 383 -0.430455  2.097191  0.379874  0.135858 -1.400176
# 384 -0.457141  0.940791 -0.660270  2.325658 -1.510055
# 385 -0.344278 -1.209805 -2.119721 -1.485907 -0.167689
# 386 -1.349114  0.715605  1.273045 -0.782789  0.683719
#
# [387 rows x 5 columns]

# %%
x.shape, y.shape
# Out:
# ((387, 5), (387, 1))

# %%
binary = LinearRegression()

# %%
binary.fit(x[[1]], y)
# Out:
# LinearRegression()

# %%
binary.coef_
# Out:
# array([[95.52010745]])

# %%
binary.predict(x[[1]])
# Out:
# array([[  81.7066754 ],
#        [ -40.45008468],
#        [ -24.60472955],
#        [ -78.92903986],
#        [ -82.26167214],
#        [  90.61516808],
#        [   3.20559483],
#        [ -27.39642608],
#        [  77.03125467],
#        [ -81.79074091],
#        [ -57.11517633],
#        [  71.55969853],
#        [ -51.83704209],
#        [  13.20326205],
#        [ -20.052765  ],
#        [ 125.1294343 ],
#        [ -85.37964253],
#        [ -67.97795874],
#        [  62.50833807],
#        [  67.06343892],
#        [ -62.27425459],
#        [ -80.86610767],
#        [ -27.05138056],
#        [ -52.78366471],
#        [  35.41921651],
#        [ -79.36741675],
#        [  56.64287014],
#        [  79.27353864],
#        [ -35.49555901],
#        [-221.02386024],
#        [ -80.76607115],
#        [ 165.15522994],
#        [  32.58309404],
#        [ -35.52849481],
#        [ -96.01738449],
#        [ -42.18812152],
#        [ -48.92932082],
#        [ -75.29745421],
#        [  14.5207672 ],
#        [  38.22303712],
#        [  -5.81538928],
#        [ -10.78305653],
#        [-160.67473236],
#        [ -24.04154649],
#        [ -11.539913  ],
#        [-153.21372804],
#        [  42.71613768],
#        [ -24.64631168],
#        [ -26.34379485],
#        [ -44.84902895],
#        [  40.59122298],
#        [  67.87447367],
#        [ 149.49931095],
#        [  -9.94584466],
#        [  72.09386938],
#        [  42.61221784],
#        [ -90.05010293],
#        [-195.17725103],
#        [  31.10609487],
#        [-179.11440495],
#        [ -68.01785401],
#        [  66.14535672],
#        [  46.04652432],
#        [-115.88877487],
#        [ -51.23726237],
#        [ -23.25825104],
#        [ 183.28767615],
#        [  42.06612485],
#        [ -61.68157548],
#        [  18.85284738],
#        [   8.29279789],
#        [  24.15702881],
#        [-132.25876571],
#        [-221.602558  ],
#        [  63.95970687],
#        [  70.05523606],
#        [ 101.35968876],
#        [  42.00528659],
#        [ -26.1669863 ],
#        [-142.57321028],
#        [  26.4302692 ],
#        [ -68.27127373],
#        [  77.68098549],
#        [   4.65591819],
#        [-275.75541696],
#        [ -18.03885794],
#        [ -65.15813567],
#        [  19.70062088],
#        [   2.30319232],
#        [-128.62567157],
#        [ -21.38042389],
#        [ 265.49792197],
#        [-232.79954877],
#        [  49.37518101],
#        [  46.59420205],
#        [ -66.70043384],
#        [ 135.3863095 ],
#        [ -20.73454969],
#        [ 153.12546539],
#        [  12.18146666],
#        [ -28.6152795 ],
#        [ 220.9291044 ],
#        [ -67.38550484],
#        [  54.67498213],
#        [ 146.49036594],
#        [-178.02357604],
#        [ 122.1816615 ],
#        [ -61.14413136],
#        [ -27.09696207],
#        [-162.71427576],
#        [ 250.11274891],
#        [-107.95714296],
#        [ -31.99055553],
#        [-125.12658808],
#        [ -43.28882518],
#        [ -48.08193349],
#        [ -14.84293043],
#        [ -49.99447436],
#        [  85.64858815],
#        [  48.0955124 ],
#        [ -12.70621587],
#        [ 106.29897038],
#        [ -18.39771021],
#        [ 131.8451858 ],
#        [ -49.15634037],
#        [   1.68833334],
#        [ 118.20821483],
#        [  93.32592767],
#        [  97.43196106],
#        [  41.90411351],
#        [-280.60718038],
#        [-197.29803704],
#        [ -81.67903369],
#        [ -31.55191845],
#        [  -8.98441752],
#        [  17.69645515],
#        [ -93.38459812],
#        [  39.46140888],
#        [ -10.04059876],
#        [ -45.14876349],
#        [ -75.91237642],
#        [-112.22661212],
#        [ 170.79517534],
#        [ 115.74079081],
#        [-162.39097497],
#        [ 105.17957504],
#        [ 154.74063944],
#        [  92.53223282],
#        [   6.9455845 ],
#        [-225.11827841],
#        [  63.11488128],
#        [  25.88212457],
#        [  39.19303711],
#        [ 141.26212896],
#        [ 122.432238  ],
#        [-263.473649  ],
#        [  -3.03374485],
#        [  97.40443477],
#        [  27.13542993],
#        [   5.3268769 ],
#        [ 109.40126709],
#        [ 187.77919778],
#        [  58.54396916],
#        [ 173.08930384],
#        [  -7.38389923],
#        [  -0.61716853],
#        [  15.9525564 ],
#        [ -56.74240282],
#        [  -9.43822359],
#        [ -12.58372954],
#        [  42.85873442],
#        [ -68.6263664 ],
#        [ -26.44110218],
#        [ -10.14910195],
#        [ -65.0326574 ],
#        [ 118.01212374],
#        [ 185.63095006],
#        [  80.68142722],
#        [ -22.36445142],
#        [  24.20376479],
#        [  91.92751024],
#        [ 123.84015615],
#        [  10.63661408],
#        [  38.14606475],
#        [  91.04662802],
#        [  -0.36732981],
#        [ 172.93200509],
#        [  15.84684686],
#        [  49.28739805],
#        [ -33.79697395],
#        [  54.96341913],
#        [ -10.50881915],
#        [-192.69059444],
#        [ -76.97685798],
#        [ 134.327864  ],
#        [ 111.50420719],
#        [ 126.56309706],
#        [-134.69906739],
#        [  75.62820656],
#        [  -1.70241194],
#        [  77.7070228 ],
#        [ -17.20936769],
#        [ 219.16998941],
#        [-136.13812314],
#        [ -66.21493546],
#        [ -55.27141374],
#        [ -70.4956149 ],
#        [ -43.24693497],
#        [  -7.07072434],
#        [ -20.91968838],
#        [ -40.80563876],
#        [ 141.13861597],
#        [  43.73042813],
#        [-195.48276684],
#        [   9.16176867],
#        [-105.62627143],
#        [ -10.67867476],
#        [   2.38472055],
#        [ 193.68921008],
#        [-115.63833686],
#        [  43.03267889],
#        [-147.37305219],
#        [  86.11484884],
#        [ -83.55847418],
#        [  30.71755434],
#        [  10.27639553],
#        [ -41.32557351],
#        [-140.26912202],
#        [ 128.01969105],
#        [ 183.95884118],
#        [   6.86531718],
#        [ -62.61269229],
#        [  66.06452798],
#        [ -47.63542055],
#        [ -85.17778107],
#        [ -15.72430026],
#        [  40.54649993],
#        [ -33.61879412],
#        [  31.76513237],
#        [-169.66712596],
#        [-110.88659879],
#        [ -77.04563955],
#        [  70.71761787],
#        [ -85.21453659],
#        [  41.92732181],
#        [ -13.68225282],
#        [ -67.49116957],
#        [  11.93379948],
#        [  50.18679576],
#        [ -21.66912636],
#        [  32.60453994],
#        [  14.09090855],
#        [ -27.33493738],
#        [-136.21711333],
#        [ -15.0605813 ],
#        [  49.78409122],
#        [-146.33455004],
#        [  71.63976509],
#        [  34.84132967],
#        [  12.30331257],
#        [  25.11261985],
#        [ -82.94602459],
#        [  83.54118867],
#        [ -57.88777693],
#        [  33.51754325],
#        [ -13.26429964],
#        [  65.85659717],
#        [  15.31444989],
#        [  67.81035688],
#        [  37.90075022],
#        [-167.10852275],
#        [ -57.99444761],
#        [ -36.00913797],
#        [  19.70290791],
#        [  33.45100315],
#        [-193.37192207],
#        [-121.15413667],
#        [  44.49224941],
#        [ -56.1373161 ],
#        [-153.69832577],
#        [ -80.50677918],
#        [-139.94014044],
#        [-192.67844919],
#        [ -54.64561087],
#        [  25.28740192],
#        [  25.07178482],
#        [   6.18083304],
#        [ 119.12500939],
#        [  46.71009304],
#        [  59.95782773],
#        [  83.74304754],
#        [ -99.02017347],
#        [ -87.68936548],
#        [  35.26396331],
#        [ 113.46685456],
#        [  42.5318588 ],
#        [  76.49714278],
#        [  99.83898538],
#        [ 112.30715761],
#        [ -12.15256336],
#        [ -29.02289519],
#        [  -6.97000698],
#        [ -37.7981597 ],
#        [ -52.4957794 ],
#        [ -98.02566506],
#        [ -18.49808937],
#        [ 134.54606734],
#        [ -21.78679736],
#        [  54.63789894],
#        [  59.63899484],
#        [ 157.32491005],
#        [  24.15363445],
#        [-121.14867961],
#        [ -32.74519018],
#        [-131.35579455],
#        [-100.53610905],
#        [  33.51745925],
#        [-221.78986989],
#        [  54.30924205],
#        [ -49.99624045],
#        [ -19.03749344],
#        [  -3.89300243],
#        [  -2.00342034],
#        [  69.27371782],
#        [ 234.02597915],
#        [  17.39055722],
#        [  14.93614571],
#        [ 148.66540159],
#        [  32.60167026],
#        [ 123.16186748],
#        [  61.24969494],
#        [  19.53920496],
#        [  25.02661721],
#        [ -75.38829513],
#        [ 166.41096829],
#        [ -47.99621481],
#        [ -25.77216712],
#        [ -48.96112576],
#        [ 105.43118884],
#        [   0.52022763],
#        [-336.85664107],
#        [  55.4750755 ],
#        [  72.33167816],
#        [-125.0236379 ],
#        [  20.70080008],
#        [ -57.91225848],
#        [  15.14114254],
#        [ -73.0099126 ],
#        [ 104.69214051],
#        [  50.24679881],
#        [  88.86557698],
#        [  68.28375578],
#        [ 122.95171668],
#        [ -25.0625463 ],
#        [  14.95429697],
#        [ -25.53926062],
#        [ 119.59087486],
#        [ 118.23947123],
#        [  43.99690047],
#        [ -21.1075395 ],
#        [ -17.25817459],
#        [  -2.62354642],
#        [  26.91692081],
#        [  10.15184644],
#        [  -9.48628965],
#        [ -81.84415436],
#        [ -68.05161774],
#        [-197.88761328],
#        [ -22.00916557],
#        [ 109.53859278],
#        [ -53.08749143],
#        [-153.71615885],
#        [  44.87328563],
#        [-157.42934885],
#        [-127.98274416],
#        [-166.53394014],
#        [ -61.33081485],
#        [ -11.77940539],
#        [  15.34513479],
#        [   3.0680711 ],
#        [-176.57818911],
#        [  13.43212536],
#        [ 221.67948236],
#        [ 200.32727577],
#        [  89.86779245],
#        [-115.55742864],
#        [  68.35801214]])

# %%
plt.scatter(x[1], y)

# %%
xx = np.linspace(x[1].min(), x[1].max(), 100).reshape((-1, 1))
plt.plot(xx, binary.predict(xx), c='r')

# %%
binary.score(x[[1]],y)
# Out:
# 0.7699743283650629

# %%
multiple = LinearRegression()
multiple.fit(x, y)
multiple.score(x, y)
# Out:
# 0.9922198026415868

# %%
yy = multiple.predict(x)
plt.scatter(yy, y)
plt.plot(yy, yy, c='r')

# %% [markdown]
# # Задания для самостоятельного выполнения

# %% [markdown]
# ## 1. Самостоятельно постройте парные регрессии от каждого атрибута с целевой переменной.

# %%
for i in range(x.shape[1]):
    display(x[[i]])
    binary = LinearRegression()
    binary.fit(x[[i]], y)
    binary.predict(x[[i]])
    plt.scatter(x[i], y)
    xx = np.linspace(x[i].min(), x[i].max(), 100).reshape((-1, 1))
    plt.plot(xx, binary.predict(xx), c='r')
    plt.show()
    print(f'Score = {binary.score(x[[i]],y)}')
# Out:
#             0
# 0    0.071841
# 1    0.139521
# 2    1.626311
# 3   -1.183233
# 4   -0.783365
# ..        ...
# 382  0.684004
# 383 -0.430455
# 384 -0.457141
# 385 -0.344278
# 386 -1.349114
#
# [387 rows x 1 columns]
# Score = 0.04364336234689348
#             1
# 0    0.855352
# 1   -0.423507
# 2   -0.257622
# 3   -0.826343
# 4   -0.861232
# ..        ...
# 382  2.320728
# 383  2.097191
# 384  0.940791
# 385 -1.209805
# 386  0.715605
#
# [387 rows x 1 columns]
# Score = 0.7699743283650629
#             2
# 0   -0.305597
# 1    0.461059
# 2   -0.697520
# 3    0.073047
# 4    0.951448
# ..        ...
# 382  0.380965
# 383  0.379874
# 384 -0.660270
# 385 -2.119721
# 386  1.273045
#
# [387 rows x 1 columns]
# Score = 0.18794528514998887
#             3
# 0    0.028253
# 1   -0.447400
# 2    1.413219
# 3   -0.639690
# 4   -0.117306
# ..        ...
# 382 -1.050408
# 383  0.135858
# 384  2.325658
# 385 -1.485907
# 386 -0.782789
#
# [387 rows x 1 columns]
# Score = 0.047470345664983093
#             4
# 0    1.826895
# 1   -0.034988
# 2    1.086292
# 3   -0.503273
# 4    0.680597
# ..        ...
# 382 -0.151801
# 383 -1.400176
# 384 -1.510055
# 385 -0.167689
# 386  0.683719
#
# [387 rows x 1 columns]
# Score = 0.00017176151145947838

# %% [markdown]
# ## 2. Модифицируйте код из предыдущей работы так, чтобы модель регрессии умела работать с входными данными, состоящими из произвольного количества столбцов.

# %%
class Model(object):
    """Модель линейной регрессии"""
    def __init__(self, shape):
        self.shape = shape
        self.b = np.zeros([self.shape[1] + 1, 1])
        self.x0 = pd.DataFrame({'x0': np.ones(self.shape[0])})
        
    def predict(self, X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all
        
        return X @ self.b
    
    def error(self,Y,X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all
            
        return 1/(2*self.shape[0]) * (Y - self.predict(X)).T @ (Y - self.predict(X))
    
    def fit(self, X, Y, alpha=0.01, accuracy=0.01, max_steps=10000):
        x_all = pd.concat([self.x0, X], axis=1)
        self.x_all = x_all
        steps, errors = [], []
        step = 0
        for _ in range(1000):
            dJ_b = -1/self.shape[0] * x_all.T @ (Y - self.predict(x_all))
            self.b -= alpha * dJ_b
            new_err = self.error(Y)
            step += 1
            steps.append(step)
            errors.append(new_err)
            
        
        
        return steps, errors, self.b
    
    
    def plot(self, Y,X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all

        yy=self.predict()
        plt.scatter(yy,Y)
        plt.plot(yy,yy,c='r')
        plt.show()
    
    def score(self, Y,X=pd.DataFrame() ):
        y_pred = self.predict()
        ss_res = np.sum((Y - y_pred)**2)
        ss_total = np.sum((Y - np.mean(Y))**2)
        r2 = 1 - (ss_res / ss_total)
        return r2


display(x.shape[1])
for j in range(5):
    for i in range(j,x.shape[1]-1):
        binary = Model(x.iloc[:,(i-j):i+1].shape)
        binary.fit(x.iloc[:,(i-j):i+1], y)
        binary.plot(y)
        print(f'Error after gradient descent = {binary.error(y).iloc[0,0]}')
        print(f'Score = {binary.score(y)[0]}')
# Out:
# 5
# Error after gradient descent = 5746.124913647154
# Score = 0.04364336213525033
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 1382.0746331007301
# Score = 0.7699743271763592
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 4879.1085330669575
# Score = 0.18794528441613068
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 5723.13106027134
# Score = 0.04747034547385187
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 1210.3233842505927
# Score = 0.7985597563773986
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 680.3029082575106
# Score = 0.8867737454635649
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 4571.528354474328
# Score = 0.23913740952536033
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 523.8366521621816
# Score = 0.9128152159967274
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 172.02745524529365
# Score = 0.9713686003713423
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 46.77232960100825
# Score = 0.9922154445727267
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %% [markdown]
# ## 3. Для целевой переменной и каждого из признаков постройте полиномиальную регрессию второго, третьего и десятого порядков. Сделайте вывод о значимости регрессии.

# %%
dictx=dict()
degrees=range(1,30)

#print(f'\n\n\nX{i}')
#dictx[f'X{i}']=[]
for deg in degrees:
        #dictx[f'{deg}']=[]
        xp=x
        pf = PolynomialFeatures(degree=deg)
        xp = pf.fit_transform(xp)
        
        binary = LinearRegression()
        start_time = dt.time()
        binary.fit(xp, y)
        stop_time=dt.time()
        
        

        
        plt.scatter(binary.predict(xp), y)
        plt.plot([np.min(y),np.max(y)],[np.min(y),np.max(y)],color='red')
        plt.show()
        print(f'Degree = {deg}')
        print(f'Study time = {(stop_time-start_time)*1000} ms')
        print(f'Score = {binary.score(xp,y)}')
        dictx[f'{deg}']=((stop_time-start_time)*1000,binary.score(xp,y))
# Out:
# Degree = 1
# Study time = 1.1317729949951172 ms
# Score = 0.9922198026415868
# Degree = 2
# Study time = 2.2819042205810547 ms
# Score = 0.9926004162659386
# Degree = 3
# Study time = 3.4787654876708984 ms
# Score = 0.9931922368118391
# Degree = 4
# Study time = 4.154443740844727 ms
# Score = 0.9943667406810202
# Degree = 5
# Study time = 8.971929550170898 ms
# Score = 0.9972316448482262
# Degree = 6
# Study time = 47.64604568481445 ms
# Score = 1.0
# Degree = 7
# Study time = 27.601242065429688 ms
# Score = 1.0
# Degree = 8
# Study time = 47.35612869262695 ms
# Score = 1.0
# Degree = 9
# Study time = 75.12259483337402 ms
# Score = 1.0
# Degree = 10
# Study time = 58.862924575805664 ms
# Score = 1.0
# Degree = 11
# Study time = 101.0885238647461 ms
# Score = 1.0
# Degree = 12
# Study time = 128.36837768554688 ms
# Score = 1.0
# Degree = 13
# Study time = 220.5638885498047 ms
# Score = 1.0
# Degree = 14
# Study time = 218.45221519470215 ms
# Score = 1.0
# Degree = 15
# Study time = 138.85259628295898 ms
# Score = 1.0
# Degree = 16
# Study time = 217.6072597503662 ms
# Score = 0.9999999999999997
# Degree = 17
# Study time = 216.9184684753418 ms
# Score = 0.9999999999976213
# Degree = 18
# Study time = 284.78431701660156 ms
# Score = 0.9999999999937726
# Degree = 19
# Study time = 357.7842712402344 ms
# Score = 0.9999999999865473
# Degree = 20
# Study time = 451.0765075683594 ms
# Score = 0.9999999972868598
# Degree = 21
# Study time = 582.611083984375 ms
# Score = 0.9999999939193258
# Degree = 22
# Study time = 722.5658893585205 ms
# Score = 0.9999999266542471
# Degree = 23
# Study time = 915.093183517456 ms
# Score = 0.9999987176605938
# Degree = 24
# Study time = 1132.3614120483398 ms
# Score = 0.9998443632372188
# Degree = 25
# Study time = 1445.9216594696045 ms
# Score = 0.9970811047685273
# Degree = 26
# Study time = 2785.301923751831 ms
# Score = 0.9899528295583073
# Degree = 27
# Study time = 3337.733507156372 ms
# Score = 0.971738655984176
# Degree = 28
# Study time = 3947.2482204437256 ms
# Score = 0.9239724840951807
# Degree = 29
# Study time = 4656.070947647095 ms
# Score = 0.940213228529791

# %% [markdown]
# Казалось бы, чем выше степень - тем лучше, но нет. Это не так. Возьмем немного больше степеней и заметим, что после 26 степени модель начинает ухудшаться

# %% [markdown]
# ## 4. Постройте сводную таблицу показателей точности всех построенных моделей. Сделайте вывод, какие модели переобученнные, какие - недообученные.

# %%
table=pd.DataFrame(np.vstack((np.array([int(i) for i in list(dictx.keys())]),*np.array(list(zip(*list(dictx.values())))))).transpose(),columns=['Degree','Study time','Score'])
table.set_index('Degree')
# Out:
#          Study time     Score
# Degree
# 1.0        1.131773  0.992220
# 2.0        2.281904  0.992600
# 3.0        3.478765  0.993192
# 4.0        4.154444  0.994367
# 5.0        8.971930  0.997232
# 6.0       47.646046  1.000000
# 7.0       27.601242  1.000000
# 8.0       47.356129  1.000000
# 9.0       75.122595  1.000000
# 10.0      58.862925  1.000000
# 11.0     101.088524  1.000000
# 12.0     128.368378  1.000000
# 13.0     220.563889  1.000000
# 14.0     218.452215  1.000000
# 15.0     138.852596  1.000000
# 16.0     217.607260  1.000000
# 17.0     216.918468  1.000000
# 18.0     284.784317  1.000000
# 19.0     357.784271  1.000000
# 20.0     451.076508  1.000000
# 21.0     582.611084  1.000000
# 22.0     722.565889  1.000000
# 23.0     915.093184  0.999999
# 24.0    1132.361412  0.999844
# 25.0    1445.921659  0.997081
# 26.0    2785.301924  0.989953
# 27.0    3337.733507  0.971739
# 28.0    3947.248220  0.923972
# 29.0    4656.070948  0.940213

# %% [markdown]
# ## 5. Используйте другие метрики качества регрессионной модели в дополнение к коэффициенту детерминации.

# %%
class Model(object):
    """Модель линейной регрессии"""
    def __init__(self, shape):
        """Initialize Model

        Args:
            shape (tuple-like): shape of X dataset
        """
        self.shape = shape
        self.b = np.zeros([self.shape[1] + 1, 1])
        self.x0 = pd.DataFrame({'x0': np.ones(self.shape[0])})
        
    def predict(self, X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all
        
        return X @ self.b
    
    def error(self,Y,X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all
            
        return 1/(2*self.shape[0]) * (Y - self.predict(X)).T @ (Y - self.predict(X))
    
    def fit(self, X, Y, alpha=0.01, accuracy=0.01, max_steps=10000):
        start_time = dt.time()
        x_all = pd.concat([self.x0, X], axis=1)
        self.x_all = x_all
        steps, errors = [], []
        step = 0
        for _ in range(1000):
            dJ_b = -1/self.shape[0] * x_all.T @ (Y - self.predict(x_all))
            self.b -= alpha * dJ_b
            new_err = self.error(Y)
            step += 1
            steps.append(step)
            errors.append(new_err)
        stop_time=dt.time()
        self.study_time_seconds = stop_time-start_time
        
        return steps, errors, self.b
    
    
    def plot(self, Y,X=pd.DataFrame()):
        if X.shape==(0,0):
            X=self.x_all

        yy=self.predict()
        plt.scatter(yy,Y)
        plt.plot(yy,yy,c='r')
        plt.show()
    
    def score(self, Y,X=pd.DataFrame() ):
        y_pred = self.predict()
        ss_res = np.sum((Y - y_pred)**2)
        ss_total = np.sum((Y - np.mean(Y))**2)
        r2 = 1 - (ss_res / ss_total)
        return r2

    def MSE(self, Y,X=pd.DataFrame() ):
        Y_pred = self.predict()
        MSE = (1/Y_pred.shape[0]) * np.sum((Y_pred - Y)**2)
        return MSE

    def RMSE(self, Y,X=pd.DataFrame() ):
        return np.sqrt(self.MSE(Y))

    def MAE(self, Y,X=pd.DataFrame() ):
        Y_pred = self.predict()
        MAE = (1/Y_pred.shape[0]) * np.sum(abs(Y_pred - Y))
        return MAE

    def MAPE(self, Y,X=pd.DataFrame() ):
        Y_pred = self.predict()
        MAPE = (1/Y_pred.shape[0]) * np.sum(abs(Y_pred - Y)/Y)*100
        return MAPE
    
    def show_metrics(self, Y,X=pd.DataFrame() ):
        text=f'''
Error after gradient descent = {self.error(y).iloc[0,0]}
Mean Absolute Percentage Error = {round(self.MAPE(y)[0],2)}%
R2 Score = {round(self.score(y)[0],4)}
Root of Mean Squared Error = {round(self.RMSE(y)[0],2)}
Mean Squared Error = {round(self.MSE(y)[0],2)}
Mean Absolute Error = {round(self.MAE(y)[0],2)}
Study Time = {self.study_time_seconds*1000} ms
        '''
        print(text)
    
    def complex_out(self,x,y):
        self.fit(x, y)
        self.plot(y)
        self.show_metrics(y)
        
for j in range(5):
    for i in range(j,x.shape[1]):
        binary = Model(x.iloc[:,(i-j):i+1].shape)
        binary.complex_out(x.iloc[:,(i-j):i+1], y)
# Out:
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 5746.124913647154
# Mean Absolute Percentage Error = 32.77%
# R2 Score = 0.0436
# Root of Mean Squared Error = 107.2
# Mean Squared Error = 11492.25
# Mean Absolute Error = 85.77
# Study Time = 1406.541347503662 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 1382.0746331007301
# Mean Absolute Percentage Error = 42.42%
# R2 Score = 0.77
# Root of Mean Squared Error = 52.58
# Mean Squared Error = 2764.15
# Mean Absolute Error = 42.13
# Study Time = 1474.912166595459 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 4879.1085330669575
# Mean Absolute Percentage Error = 43.64%
# R2 Score = 0.1879
# Root of Mean Squared Error = 98.78
# Mean Squared Error = 9758.22
# Mean Absolute Error = 77.41
# Study Time = 1409.9066257476807 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 5723.13106027134
# Mean Absolute Percentage Error = 45.88%
# R2 Score = 0.0475
# Root of Mean Squared Error = 106.99
# Mean Squared Error = 11446.26
# Mean Absolute Error = 83.59
# Study Time = 1416.377305984497 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 6007.317482962355
# Mean Absolute Percentage Error = 9.0%
# R2 Score = 0.0002
# Root of Mean Squared Error = 109.61
# Mean Squared Error = 12014.63
# Mean Absolute Error = 87.2
# Study Time = 1425.295352935791 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 1210.3233842505927
# Mean Absolute Percentage Error = 15.7%
# R2 Score = 0.7986
# Root of Mean Squared Error = 49.2
# Mean Squared Error = 2420.65
# Mean Absolute Error = 38.83
# Study Time = 1477.999210357666 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 680.3029082575106
# Mean Absolute Percentage Error = 37.72%
# R2 Score = 0.8868
# Root of Mean Squared Error = 36.89
# Mean Squared Error = 1360.61
# Mean Absolute Error = 30.13
# Study Time = 1424.0834712982178 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 4571.528354474328
# Mean Absolute Percentage Error = 15.33%
# R2 Score = 0.2391
# Root of Mean Squared Error = 95.62
# Mean Squared Error = 9143.06
# Mean Absolute Error = 74.32
# Study Time = 1448.9047527313232 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 5722.376889708814
# Mean Absolute Percentage Error = 44.3%
# R2 Score = 0.0476
# Root of Mean Squared Error = 106.98
# Mean Squared Error = 11444.75
# Mean Absolute Error = 83.57
# Study Time = 1596.5211391448975 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 523.8366521621816
# Mean Absolute Percentage Error = 53.88%
# R2 Score = 0.9128
# Root of Mean Squared Error = 32.37
# Mean Squared Error = 1047.67
# Mean Absolute Error = 25.78
# Study Time = 1423.6435890197754 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 172.02745524529365
# Mean Absolute Percentage Error = 32.13%
# R2 Score = 0.9714
# Root of Mean Squared Error = 18.55
# Mean Squared Error = 344.05
# Mean Absolute Error = 14.86
# Study Time = 1404.9603939056396 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 4565.47518017273
# Mean Absolute Percentage Error = 17.02%
# R2 Score = 0.2401
# Root of Mean Squared Error = 95.56
# Mean Squared Error = 9130.95
# Mean Absolute Error = 74.3
# Study Time = 1437.833309173584 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 46.77232960100825
# Mean Absolute Percentage Error = 4.85%
# R2 Score = 0.9922
# Root of Mean Squared Error = 9.67
# Mean Squared Error = 93.54
# Mean Absolute Error = 7.79
# Study Time = 1352.4887561798096 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# Error after gradient descent = 172.0255230227051
# Mean Absolute Percentage Error = 32.17%
# R2 Score = 0.9714
# Root of Mean Squared Error = 18.55
# Mean Squared Error = 344.05
# Mean Absolute Error = 14.86
# Study Time = 1412.520170211792 ms
# Error after gradient descent = 46.74619396408136
# Mean Absolute Percentage Error = 5.07%
# R2 Score = 0.9922
# Root of Mean Squared Error = 9.67
# Mean Squared Error = 93.49
# Mean Absolute Error = 7.78
# Study Time = 1409.9340438842773 ms
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# c:\Users\ivant\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
