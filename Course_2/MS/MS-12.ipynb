# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sympy import *
from functools import reduce
from IPython.display import Math

from math import comb

def bernulli(n,i,p):
    return comb(n,i)*p**i*(1-p)**(n-i)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
x=np.array([29, 23, 25, 24, 9, 18, 36, 27, 33, 20, 12, 40, 29, 22, 30, 9, 39, 5, 20, 59])
x
# Out:
# array([29, 23, 25, 24,  9, 18, 36, 27, 33, 20, 12, 40, 29, 22, 30,  9, 39,
#         5, 20, 59])

# %%
g=0.95
n=x.size
mu=x.mean()
s=10
display(Math('Interval = ' + latex(st.norm.interval(g,mu,s/np.sqrt(n)))))
# Out:
# $\displaystyle Interval = \left( 21.0673872971171, \  29.8326127028829\right)$

# %%
#a для математического ожидания генеральной совокупности при известной дисперсии (sigma^2=100)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sigma=x.var()**0.5
s=10
mu - st.norm.ppf((1+g)/2)*s/np.sqrt(n),mu + st.norm.ppf((1+g)/2)*s/np.sqrt(n)
# Out:
# (21.067387297117094, 29.832612702882905)

# %%
# Функция "выживания" (Survival function (sf) P(X ⩾ q)

# Функция обратная к функции выживания (Inverse survival function (inverse of sf)) (isf).
# Найти q, так чтобы P(X ⩾ q) = h
# X.isf(h)

# Можно вычислить и так z_(1+gamma)/2:
a=1-g
st.norm.isf(a/2)
# Out:
# 1.959963984540054

# %%
mu - st.norm.ppf((1+g)/2)*s/np.sqrt(n),mu+ st.norm.ppf((1+g)/2)*s/np.sqrt(n)
# Out:
# (21.067387297117094, 29.832612702882905)

# %%
st.norm.interval(g,mu, (1+g)/2*s/np.sqrt(n))
# Out:
# (21.176952614689164, 29.723047385310835)

# %%
# Можно вычислить и так:

# %%
# b) для математического ожидания при неизвестной дисперсии;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# несмещённая оценка (СТАНДОТКЛОН.В)

# %%
s=x.std(ddof=0)
mu-st.t.ppf((1+g)/2,n-1)*s/np.sqrt(n),mu+st.t.ppf((1+g)/2,n-1)*s/np.sqrt(n)
# Out:
# (19.705659353435223, 31.194340646564775)

# %%
# Можно вычислить и так:

# %%
# c) для дисперсии генеральной совокупности при известном математическом ожидании E(X)=25;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mu = 25
s02 = sum((x-mu)**2)/n
s02
# Out:
# 150.85

# %%
n*s02/st.chi2.ppf((1+g)/2,n),n*s02/st.chi2.ppf((1-g)/2,n)
# Out:
# (88.2948407506962, 314.5730399741385)

# %%
# d) для дисперсии при неизвестном математическом ожидании.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s2 = sum((x-mu)**2/(n-1))
s2
# Out:
# 158.78947368421052

# %%
n*s2/st.chi2.ppf((1+g)/2,n-1),n*s2/st.chi2.ppf((1-g)/2,n-1)
# Out:
# (96.66863132863044, 356.569201899165)

# %%
# Вычисление используя Функция обратную к функции выживания 
# (Inverse survival function (inverse of sf)) (isf).
# Найти q, так чтобы P(X ⩾ q) =h

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
n=400
k=20
mu1=177.8
s1=7.62
mu2=165.1
s2=6.35

M=st.norm(mu1,s1)
W=st.norm(mu2,s2)

mu3=mu1-mu2
s3=(s1**2-s2**2)**0.5

Z=st.norm(mu3,s3)

p=k/n 
q=1-p

z_g=st.norm.ppf((1+g)/2)
mu3 - z_g*np.sqrt(p*q/n), mu3 +z_g*np.sqrt(p*q/n)
# Out:
# (12.678641787646043, 12.72135821235399)

# %%
Z.sf(0)
# Out:
# 0.9987155842364887

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# а) Доверительный интервал для доли аспирантов, специализирующихся в финтех-предпринимательстве (отцы-банкиры)
N=2000
n=200
m=90
p=m/n 
q=1-p

g=0.9
p-st.norm.ppf((1+g)/2)*np.sqrt(p*q/n ),p+st.norm.ppf((1+g)/2)*np.sqrt(p*q/n )
# Out:
# (0.3921371446915807, 0.5078628553084193)

# %%
# б) - число таких аспирантов среди N=2000 аспирантов.

# %%
N*(p-st.norm.ppf((1+g)/2)*np.sqrt(p*q/n )),N*(p+st.norm.ppf((1+g)/2)*np.sqrt(p*q/n ))
# Out:
# (784.2742893831613, 1015.7257106168387)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=5
mu=0.20
s=0.05
g=0.97

d=st.t.ppf((1+g)/2,n-1)*s*np.sqrt(1+1/n)
mu-d,mu+d
# Out:
# (0.019381381173454282, 0.38061861882654574)

# %% [markdown]
# $S_0 + S_0\cdot(\bar x-\delta) < S <  S_0 + S_0\cdot(\bar x-\delta), \qquad S_0=100$

# %%
s0=100
d=st.t.ppf((1+g)/2,n-1)*s*np.sqrt(1+1/n)
mu-d,mu+d

s0+s0*(mu-d),s0+s0*(mu+d)
# Out:
# (101.93813811734543, 138.06186188265457)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gamma=0.93

# %%
x_data ='-0,616; -0,238; 0,173; -0,255; 0,531; 0,718; -0,161; 0,371; \
-1,014; -0,413; -1,571; 0,485; 0,486; 0,688; -0,944; 0,155; 0,003; \
0,111; 0,752; 0,783; -0,102; -0,74; -2,097; 1,349; -0,044; -0,617; \
-0,782; -0,873; -0,995; -1,256; -0,596'.replace(',','.').split('; ')

# %%
y_data ='-1,34; -0,25; 0,101; -0,626; -0,088; 0,539; -0,451; 0,233; \
-1,186; -0,423; -1,329; 0,231; 0,209; 0,638; -0,274; -0,491; -0,319; \
0,294; 0,895; 1,164; -0,57; -1,078; -1,526; 1,491; 0,182; -0,31; -1,001;\
-0,969; -0,918; -0,904; -0,595'.replace(',','.').split(';')

# %%
x_data=np.array(x_data).astype(float)
y_data=np.array(y_data).astype(float)

# %%
np.corrcoef(x_data,y_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 np.corrcoef(x_data,y_data)
#
# File c:\Users\ivant\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2889, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2885 if bias is not np._NoValue or ddof is not np._NoValue:
#    2886     # 2015-03-15, 1.10
#    2887     warnings.warn('bias and ddof have no effect and are deprecated',
#    2888                   DeprecationWarning, stacklevel=2)
# -> 2889 c = cov(x, y, rowvar, dtype=dtype)
#    2890 try:
#    2891     d = diag(c)
#
# File c:\Users\ivant\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2683, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2681     if not rowvar and y.shape[0] != 1:
#    2682         y = y.T
# -> 2683     X = np.concatenate((X, y), axis=0)
#    2685 if ddof is None:
#    2686     if bias == 0:
#
# ...

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
53/60
# Out:
# 0.8833333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
