# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sympy import *
from functools import reduce
from IPython.display import Math

from math import comb

def bernulli(n,i,p):
    return comb(n,i)*p**i*(1-p)**(n-i)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %%
g = 0.99
n = 100
m = 60
z = st.t.ppf((g+1)/2,n-1)
p = m/n
q = 1-p
delta = z * np.sqrt(p*q/n)
(p-delta,p+delta)
# Out:
# (0.471332935440017, 0.728667064559983)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %%
n = 400
m = 5
p = m/n
q = 1-p
g = 0.999

t = st.t.ppf((g+1)/2,n-1)
d = t * np.sqrt(p*q/n)

(max(p-d,0),p+d)
# Out:
# (0, 0.03091565562292998)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %%
n = 360
m = 270
p = m/n
q = 1-p
g = 0.95
t = st.t.ppf((g+1)/2,n-1)
d = t * np.sqrt(p*q/n)

(p-d,p+d)
# Out:
# (0.705118839117979, 0.794881160882021)

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ### a)

# %%
n = 1000
m = 100
p = m/n
q = 1-p
g = 0.95
t = st.t.ppf((g+1)/2,n-1)
d = t * np.sqrt(p*q/n)

(p-d,p+d)
# Out:
# (0.08138359430750657, 0.11861640569249345)

# %% [markdown]
# ### b)

# %%
n = 1000
m = 100
p = m/n
q = 1-p
g = 0.99
t = st.t.ppf((g+1)/2,n-1)
d = t * np.sqrt(p*q/n)

(p-d,p+d)
# Out:
# (0.075516764358413, 0.12448323564158702)
