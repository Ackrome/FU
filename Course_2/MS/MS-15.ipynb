# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sts
from matplobblib.tvims import *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('Res_session.csv', encoding='cp1251', sep = ';', names = range(5), header = 0)

n = [np.array(df.iloc[:,i].dropna()) for i in range(5)]

q = [i.size for i in n]
N = sum(q)

avg = np.array([i.mean() for i in n])
E_n = np.multiply(avg,q).sum()/N


var = np.array([i.var() for i in n])

Var_n = np.multiply(var,q).sum()/N

Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N

print('Групповые средние = ', np.vectorize(rrstr)(avg,3))
print('Общее среднее = ' + rrstr(E_n,3))
print('Внутригрупповые дисперсии = ', np.vectorize(rrstr)(var,3))
print('Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
# Out:
# Групповые средние =  ['81,964' '79,310' '74,750' '78,000' '54,542']
# Общее среднее = 74,244
# Внутригрупповые дисперсии =  ['218,106' '203,524' '402,021' '497,846' '290,915']
# Средняя групповая дисперсия = 317,432
# Межгрупповая дисперсия = 92,386
# Общая дисперсия по правилу сложения = 409,818

# %% [markdown]
# # В экзамен

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q = [20,18,19]
avg = np.array([79,64,79])
var = np.array([6,14,19])**2

N = sum(q)
E_n = np.multiply(avg,q).sum()/N
Var_n = np.multiply(var,q).sum()/N
Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N
Var = (Var_n_gr+Var_n)
n=20
Var_x_ = Var/n * (N-n)/(N-1)

print('Всего людей = '+ str(N))
print('Общее среднее = ' + rrstr(E_n,3))
print('Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
print('Дисперсия выборки = ' + rrstr(Var_x_,3))
# Out:
# Всего людей = 57
# Общее среднее = 74,263
# Средняя групповая дисперсия = 194,860
# Межгрупповая дисперсия = 48,615
# Общая дисперсия по правилу сложения = 243,475
# Дисперсия выборки = 8,043

# %%
n = []
n.append(np.array('10, 15, 20, 17, 12, 15, 15, 15, 20, 20, 17, 12, 15, 20, 17'.split(',')).astype(int))
n.append(np.array('20, 25, 25, 20, 18, 17, 17, 18, 20, 20'.split(',')).astype(int))
n.append(np.array('15, 15, 20, 17, 17, 20, 20, 15, 18, 18, 17, 25, 20, 15, 18'.split(',')).astype(int))

q = [i.size for i in n]
N = sum(q)

avg = np.array([i.mean() for i in n])
E_n = np.multiply(avg,q).sum()/N
var = np.array([i.var() for i in n])
Var_n = np.multiply(var,q).sum()/N
Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N
Var = (Var_n_gr+Var_n)
n=20
Var_x_ = Var/n * (N-n)/(N-1)

print('Всего людей = '+ str(N))
print('Групповые средние = ', np.vectorize(rrstr)(avg,3))
print('Общее среднее = ' + rrstr(E_n,3))
print('Внутригрупповые дисперсии = ', np.vectorize(rrstr)(var,3))
print('Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
print('Дисперсия выборки = ' + rrstr(Var_x_,3))
# Out:
# Всего людей = 40
# Групповые средние =  ['16,000' '20,000' '18,000']
# Общее среднее = 17,750
# Внутригрупповые дисперсии =  ['9,333' '7,600' '6,933']
# Средняя групповая дисперсия = 8,000
# Межгрупповая дисперсия = 2,438
# Общая дисперсия по правилу сложения = 10,438
# Дисперсия выборки = 0,268

# %% [markdown]
# # Экзамен

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q = [24,26,30]
avg = np.array([70,76,77])
var = np.array([4,6,8])**2

N = sum(q)
E_n = np.multiply(avg,q).sum()/N
Var_n = np.multiply(var,q).sum()/N
Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N
Var = (Var_n_gr+Var_n)
n=20
Var_x_ = Var/n * (N-n)/(N-1)

print('Всего людей = '+ str(N))
print('Общее среднее = ' + rrstr(E_n,3))
print('Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
print('Общее стандартное отклоенение по правилу сложения = ' + rrstr(Var**0.5,3))
print('Дисперсия выборки = ' + rrstr(Var_x_,3))
# Out:
# Всего людей = 80
# Общее среднее = 74,575
# Средняя групповая дисперсия = 40,500
# Межгрупповая дисперсия = 9,144
# Общая дисперсия по правилу сложения = 49,644
# Общее стандартное отклоенение по правилу сложения = 7,046
# Дисперсия выборки = 1,885

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
n = []
n.append(np.array('''13
14
15
17
16
15'''.split('\n')).astype(int))
n.append(np.array('''18
19
22
20
24
23'''.split('\n')).astype(int))

q = [i.size for i in n]
N = sum(q)

avg = np.array([i.mean() for i in n])
E_n = np.multiply(avg,q).sum()/N
var = np.array([i.var() for i in n])
Var_n = np.multiply(var,q).sum()/N
Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N
Var = (Var_n_gr+Var_n)
n=20
Var_x_ = Var/n * (N-n)/(N-1)

print('Всего людей = '+ str(N))
print('Групповые средние = ', np.vectorize(rrstr)(avg,3))
print('Общее среднее = ' + rrstr(E_n,3))
print('1) Внутригрупповые дисперсии = ', np.vectorize(rrstr)(var,3))
print('2) Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('3) Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('4) Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
print('Общее стандартное отклоенение по правилу сложения = ' + rrstr(Var**0.5,3))
print('Дисперсия выборки = ' + rrstr(Var_x_,3))
# Out:
# Всего людей = 12
# Групповые средние =  ['15,000' '21,000']
# Общее среднее = 18,000
# 1) Внутригрупповые дисперсии =  ['1,667' '4,667']
# 2) Средняя групповая дисперсия = 3,167
# 3) Межгрупповая дисперсия = 9,000
# 4) Общая дисперсия по правилу сложения = 12,167
# Общее стандартное отклоенение по правилу сложения = 3,488
# Дисперсия выборки = -0,442

# %% [markdown]
# # 2
# Для анализа возьмем три группы сотрудников, работающих в разных отделах компании, и их данные о заработной плате (в тысячах рублей):
#
# $$
# X_1 = \{50,55,52,48,51 \}\\
# X_2 = \{60,65,62,58,64\}\\
# X_3 = \{70,75,72,68,74 \}
# $$
# Определите:
#  1) групповые и общую среднюю;
#  2)  внутригрупповые и межгрупповую дисперсию,
#  3)  общую дисперсию по правилу сложения.

# %%
n = []
n.append(np.array('''50,55,52,48,51'''.split(',')).astype(int))
n.append(np.array('''60,65,62,58,64'''.split(',')).astype(int))
n.append(np.array('''70,75,72,68,74'''.split(',')).astype(int))

q = [i.size for i in n]
N = sum(q)

avg = np.array([i.mean() for i in n])
E_n = np.multiply(avg,q).sum()/N
var = np.array([i.var() for i in n])
Var_n = np.multiply(var,q).sum()/N
Var_n_gr =np.multiply( np.subtract(E_n,avg)**2,q).sum()/N
Var = (Var_n_gr+Var_n)

print('Всего людей = '+ str(N))
print('Групповые средние = ', np.vectorize(rrstr)(avg,3))
print('Общее среднее = ' + rrstr(E_n,3))
print('Внутригрупповые дисперсии = ', np.vectorize(rrstr)(var,3))
print('Средняя групповая дисперсия = ' + rrstr(Var_n,3))
print('Межгрупповая дисперсия = ' + rrstr(Var_n_gr,3))
print('Общая дисперсия по правилу сложения = ' + rrstr(Var_n_gr+Var_n,3))
print('Общее стандартное отклоенение по правилу сложения = ' + rrstr(Var**0.5,3))
# Out:
# Всего людей = 15
# Групповые средние =  ['51,200' '61,800' '71,800']
# Общее среднее = 61,600
# Внутригрупповые дисперсии =  ['5,360' '6,560' '6,560']
# Средняя групповая дисперсия = 6,160
# Межгрупповая дисперсия = 70,747
# Общая дисперсия по правилу сложения = 76,907
# Общее стандартное отклоенение по правилу сложения = 8,770
