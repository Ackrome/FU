# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sympy import *
from functools import reduce
from IPython.display import Math

from math import comb

def bernulli(n,i,p):
    return comb(n,i)*p**i*(1-p)**(n-i)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=9
mu=187.9
s=32.4
y=0.8
X = st.norm(mu,s)
R=[X.ppf((1-y)/2),X.ppf(1-(1-y)/2)]
z_gamma = st.norm.ppf((1+y)/2)
delta=z_gamma*s/np.sqrt(n)
mu-delta,mu+delta
# Out:
# (174.05924309211832, 201.7407569078817)

# %%
Math('Interval = ' + latex(st.norm.interval(y,mu,s/np.sqrt(n))))
# Out:
# $\displaystyle Interval = \left( 174.059243092118, \  201.740756907882\right)$

# %%
new_inter=(165.8,210.0)
g_1=2*st.norm.cdf(np.sqrt(n)/s*(mu-new_inter[0]))-1
Math('\gamma_1 = ' +latex(g_1))
# Out:
# $\displaystyle \gamma_1 = 0.959272772114279$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X=np.repeat([-2,1,2,3,4,5],[2,1,2,2,2,1])
g=0.95

mu=X.mean()
s=np.sqrt(((X-mu)**2).sum()/(X.size-1))
t_g=st.t.ppf((1+g)/2,(X.size-1))
d=t_g*s/X.size**0.5
Math('Interval = ' + latex((mu-d,mu+d)))
t_g
# Out:
# 2.2621571628540993

# %%
Math('Interval = ' + latex(st.t.interval(g,(X.size-1),mu,s/np.sqrt((X.size)))))
# Out:
# $\displaystyle Interval = \left( 0.280495996801178, \  3.71950400319882\right)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s=8
g=0.94
mu=33
n=99
display(Math('Interval = ' + latex(st.t.interval(g,(n-1),mu,s/np.sqrt(n)))))
s=8
display(Math('Interval = ' + latex(st.norm.interval(g,mu,s/np.sqrt(n)))))
# Out:
# $\displaystyle Interval = \left( 31.4700790930237, \  34.5299209069763\right)$
# $\displaystyle Interval = \left( 31.4877850408881, \  34.5122149591119\right)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g=0.9
mu=33
n=99
sigma=120
display(Math('Interval = ' + latex(st.norm.interval(g,mu,sigma/np.sqrt(n)))))
# Out:
# $\displaystyle Interval = \left( 13.16231885217, \  52.83768114783\right)$

# %%
(st.norm.ppf((1+g)/2)*sigma/10)**2
# Out:
# 389.5982573897394

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=24
X=np.array([70,91,92,83,78,115,82,30,98,116,80,150,200,88,70,90,160,100,86,76,90,140,76,68])
g=0.92
mu=X.mean()
sigma=X.var()
s=np.sqrt(((X-mu)**2).sum()/(n-1))
t_g=st.t.ppf((1+g)/2,(n-1))
d=t_g*s/X.size**0.5
display(Math('Interval = ' + latex((mu-d,mu+d))))
display(Math('Interval = ' + latex(st.norm.interval(g,mu,sigma/np.sqrt(n)))))
(st.norm.ppf((1+g)/2)*s/delta)**2
# Out:
# $\displaystyle Interval = \left( 83.758585500828, \  110.324747832505\right)$
# $\displaystyle Interval = \left( -355.22767418574, \  549.311007519073\right)$
# 42987.035717264975

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g=0.95
mu=0.007
s=0.04
n=52
i =st.t.interval(g,n-1,mu,s/n**0.5)
i
# Out:
# (-0.004136071113327796, 0.018136071113327795)

# %%
g_1 = st.t.cdf(n**0.5/s * mu,(n-1))
g_1
# Out:
# 0.8936449046034166

# %%
mu-s/n**0.5 * st.t.ppf(g_1,(n-1))
# Out:
# -8.673617379884035e-19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X=np.repeat([-0.5,-0.4,-0.2,0,0.2, 0.6, 0.8, 1, 1.2, 1.5 ], [2,1,2,1,1,1,1,1,2,1])
n=12
g=0.95
mu=X.mean()
sigma=X.var()

display(Math('Interval = ' + latex(st.t.interval(g,(n-1),mu,sigma**0.5/np.sqrt(n)))))
# Out:
# $\displaystyle Interval = \left( -0.0776263267114496, \  0.800703249788373\right)$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g=0.975
delta=0.3
sigma=1.2

(st.norm.ppf((1+g)/2)*sigma/delta)**2
# Out:
# 80.38217899703832
