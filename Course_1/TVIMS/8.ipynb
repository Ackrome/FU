# %%
import numpy as np
from scipy.stats import *
from scipy.special import *
from itertools import *
from more_itertools import *
import sympy as sp
import math
import statistics as statsv
import pandas as pd
from fractions import Fraction
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import rcParams
from tqdm.notebook import tqdm
import functools as ft
#########################
import locale
locale.setlocale(locale.LC_NUMERIC, 'russian')
plt.rcParams['axes.formatter.use_locale'] = True
#########
#########
plt.rcParams['font.size'] = 36
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['mathtext.fontset'] = 'cm'
###################
sp.init_printing(use_unicode=True,use_latex=True)

# %% [markdown]
# ## Задачи: <a class="anchor" id="разделы"></a>
# * [8.1](#8.1)
# * [8.2](#8.2)
# * [8.3](#8.3)
# * [8.4](#8.4)
# * [8.5](#8.5)
# * [8.6](#8.6)
# * [8.8](#8.8)
# * [8.8](#8.8)
# * [8.9](#8.9)
# * [8.10](#8.10)
# * [8.11](#8.11)

# %% [markdown]
# # 8.1

# %%
X = geom(1/4)

# %%
X.var()
# Out:
# 12.0

# %%
X.mean()
# Out:
# 4.0

# %%
X.median()
# Out:
# 3.0

# %%
N=100_000
x = list(range(1,N+1))


rcParams['figure.figsize'] = (15, 5)
rcParams['figure.dpi'] = 300
fig, ax = plt.subplots(figsize=(10, 5))
plt.tick_params(labelsize=16)
plt.grid(color='DarkTurquoise', alpha=0.75, linestyle=':', linewidth=1)
ax.xaxis.set_major_locator(ticker.MaxNLocator(8))
ax.xaxis.set_minor_locator(ticker.MaxNLocator(15))

hel = list(X.rvs(size=N))
y = [sum(hel[0:i])/i for i in tqdm(range(1,N+1))]

plt.ylim(y[-1]*0.995, y[-1]*1.005)
plt.xlim(100, N)
plt.plot(x, y, color='b', lw=1)
plt.plot(x,[y[-1]]*len(x),color='r',lw=2)
plt.show()
print(y[-1])
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 4.00767

# %% [markdown]
# # 8.2

# %%
X = geom(1/12)

# %%
X.var()
# Out:
# 132.0

# %%
X.mean()
# Out:
# 12.0

# %%
N=100_000
x = list(range(1,N+1))


rcParams['figure.figsize'] = (15, 5)
rcParams['figure.dpi'] = 300
fig, ax = plt.subplots(figsize=(10, 5))
plt.tick_params(labelsize=16)
plt.grid(color='DarkTurquoise', alpha=0.75, linestyle=':', linewidth=1)
ax.xaxis.set_major_locator(ticker.MaxNLocator(8))
ax.xaxis.set_minor_locator(ticker.MaxNLocator(15))

hel = list(X.rvs(size=N))
y = [sum(hel[0:i])/i for i in tqdm(range(1,N+1))]

plt.ylim(y[-1]*0.995, y[-1]*1.005)
plt.xlim(100, N)
plt.plot(x, y, color='b', lw=1)
plt.plot(x,[y[-1]]*len(x),color='r',lw=2)
plt.show()
print(y[-1])
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# 11.9783

# %% [markdown]
# # 8.3

# %%
X = rv_discrete(values=(np.arange(1, 6+1), np.array([i / 21 for i in range(1, 6+1)])))

# %%
N = 50_000
x = []
y = []
sample = []
for i in tqdm(range(1, N+1)):
    x.append(i)
    n = []
    while any([(i not in set(n)) for i in [2,4,6]]):
        n.append(X.rvs(size=1)[0])
        
    sample.append(len(n))
    
    y.append(sum(sample) / i)

y[-1]
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# 12.7142

# %%
rcParams['figure.figsize'] = (15, 5)
rcParams['figure.dpi'] = 300
fig, ax = plt.subplots(figsize=(10, 5))
plt.tick_params(labelsize=16)
plt.grid(color='DarkTurquoise', alpha=0.75, linestyle=':', linewidth=1)
ax.xaxis.set_major_locator(ticker.MaxNLocator(8))
ax.xaxis.set_minor_locator(ticker.MaxNLocator(15))
plt.ylim(y[-1]*0.995, y[-1]*1.005)
plt.xlim(100, N)
plt.plot(x, y, color='b', lw=1)
plt.plot(x,[y[-1]]*len(x),color='r',lw=2)
plt.show()
y[-1]
# Out:
# 12.7142

# %%
Var=sum([i**2 for i in sample])/ len(sample) - y[-1]**2
Var
# Out:
# 80.33775836000001

# %%
N = 50_000
x = []
y = []
sample = []
for i in tqdm(range(1, N+1)):
    x.append(i)
    n = []
    while len(set(n) & ({2,4,6}))!=2:
        n.append(X.rvs(size=1)[0])
        
    sample.append(len(n))
    
    y.append(sum(sample) / i)

huk = y[-1]
huk
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# 4.74354

# %%
x = []
y = []
sample = []
for i in tqdm(range(1, N+1)):
    x.append(i)
    n = []
    while all([(i not in set(n)) for i in [2,4,6]]):
        n.append(X.rvs(size=1)[0])
        
    sample.append(len(n))
    
    y.append(sum(sample) / i)

lev = y[-1]
lev
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# 1.75166

# %%
huk - lev
# Out:
# 2.99188

# %% [markdown]
# # 8.4

# %%
X=rv_discrete(values=([0,1,2,3],[0.4,0.3,0.2,0.1]))

# %%
X.expect(lambda x: (x-X.expect())**2)
# Out:
# 1.0

# %%
X.expect(lambda x: (x-1)**3)
# Out:
# 0.6000000000000001

# %%
X.expect(lambda x: (x-1)**4)
# Out:
# 2.2

# %%
X.expect(lambda x: (x-1)**3)/(X.var()**1.5)
# Out:
# 0.6000000000000001

# %%
X.expect(lambda x: (x-1)**4)/(X.var()**2) - 3
# Out:
# -0.7999999999999998

# %% [markdown]
# # 8.5

# %%
X=rv_discrete(values=([1,2,3,4,5],[1/6,1/6,2/6,1/6,1/6]))

# %%
X.expect(lambda x: (x-X.expect())**3)/(X.var()**1.5)
# Out:
# 0.0

# %%
X.moment(X.expect())
# Out:
# 42.0

# %%
(X.expect(lambda x: (x - X.expect())**4)/(X.var()**2) - 3)/24
# Out:
# -0.039999999999999945

# %% [markdown]
# # 8.6

# %% [markdown]
# $$
# As(X) = \frac{0,096(b^3-a^3)+0,288ab(a-b)}{(0,4a-0,4b)^3} = -\frac{3}{2}
# $$

# %% [markdown]
# $$
# \mathbb{E}(X) = \frac{b^4+a^4-4ab(a^2+b^2)+6a^2b^2}{4(a-b)^4}
# $$

# %% [markdown]
# $$
# As(X1 + . . . Xn) = \frac{1}{\sqrt{n}}\\
# As(X1) → 0\\
# Ex(X1 + . . . Xn) = \frac{1}{n}\\
# Ex(X1) → 0, n → +∞.
# $$

# %% [markdown]
# # 8.7

# %% [markdown]
# $$
# X \sim \Pi(\lambda)\\
# $$
# >$$
# Теорема\\
# \mathbb{E}(X) = Var(X) = \lambda\\
# $$

# %% [markdown]
# $$
# \mu_k = \sum_{i=0}^{k} \lambda^i \bigg\{
# \begin{array}{c}
#     k \\
#     i
# \end{array}\bigg\} = \sum_{i=0}^{k} \frac{\lambda^i}{k!} \cdot \sum_{j=0}^{k} (-1)^{j+k} \cdot\bigg(\begin{array}{c}
#       k \\
#       j
#     \end{array}\bigg) \cdot j^i
# $$

# %% [markdown]
# $$
# \mu_3 = \sum_{i=0}^{3} \frac{\lambda^i}{3!} \sum_{j=0}^{3} (-1)^{j} \bigg(\begin{array}{c}
#       3 \\
#       j
#     \end{array}\bigg) \cdot j^i = \lambda
# $$

# %% [markdown]
# $$
# \sigma_X = \sqrt{Var(X)} = \sqrt{\lambda}\\
# As(X) = \lambda^{-\frac{1}{2}}
# $$

# %% [markdown]
# # 8.8

# %% [markdown]
# $$
# Kurt(X) \geq As(X)^2 +1\\
# Ex(X) = Kurt(X) -3\\
# Ex(X)\geq As(X)^2 -2\\
# As(X)^2 \geq 0 - всегда\\
# Ex(X)\geq -2\\
# $$

# %% [markdown]
# # 8.9

# %% [markdown]
# $$
# X \sim \Pi(\lambda_{X})\\
# Y \sim \Pi(\lambda_{Y})\\
# Z \sim \Pi(\lambda_{Z})\\
# $$

# %% [markdown]
# >$$
# Теорема\\
# \mathbb{E}(X) = Var(X) = \lambda_{X}\\
# \mathbb{E}(Y) = Var(Y) = \lambda_{Y}\\
# \mathbb{E}(Z) = Var(Z) = \lambda_{Z}\\
# $$

# %% [markdown]
# $$
# \sigma_X = 0,3\\
# \sigma_Y = 0,9\\
# \sigma_Z = 1,8\\
# $$

# %% [markdown]
# >$$
# \sigma_X = \sqrt{Var(X)} = \sqrt{\lambda}\\
# $$

# %% [markdown]
# $$
# \mathbb{E}(X) = Var(X) = \lambda_{X} = \sigma_X^2 = 0,3^2 = 0,09\\
# \mathbb{E}(Y) = Var(Y) = \lambda_{Y} = \sigma_Y^2 = 0,9^2 = 0,81\\
# \mathbb{E}(Z) = Var(Z) = \lambda_{Z} = \sigma_Z^2 = 1,8^2 = 3,24\\
# $$

# %% [markdown]
# >$$
# \mathbb{P}(S=k)=\frac{\lambda_S^k}{k!}\cdot e^{-\lambda}
# $$

# %% [markdown]
# $$
# 1)\\
# \lambda_S = \lambda_{X}+\lambda_{Y}+\lambda_{Z} = 0,09 + 0,81 + 3,24 = 4,14\\
# \mathbb{P}(S=7)=\frac{\lambda_S^7}{7!}\cdot e^{-\lambda} = \frac{4,14^7}{7!}\cdot e^{-4,14} \approx 0,0658556
# $$

# %% [markdown]
# $$
# 2)\\
# S = X + Y + Z
# $$
# Наиболее вероятное значение $S$ - это его математическое ожидание:
# $$
# [\mathbb{E}(S)] = [\mathbb{E}(X + Y + Z) = \mathbb{E}(X) + \mathbb{E}(Y) + \mathbb{E}(Z)] = \\
# = [0,09 + 0,81 + 3,24] = [4,14] = 4
# $$

# %% [markdown]
# $$
# 3)\\
# \sigma_S = \sqrt{\mathbb{V}ar(X)+\mathbb{V}ar(Y)+\mathbb{V}ar(Z)}\\
# \sigma_S = 0,3 \cdot \sqrt{46} \approx 2,0347
# $$

# %% [markdown]
# $$
# 4.1)\\
# As(S) = x_1 \cdot As(X) + y_1 \cdot As(Y) +z_1\cdot As(Z)\\
# $$

# %% [markdown]
# >$$As(X) = \frac{1}{\sqrt{\lambda_X}} = \frac{1}{\sigma_X} $$

# %% [markdown]
# $$
# As(X) = \frac{10}{3}
# $$<br>
# $$
# As(Y) = \frac{10}{9}\\
# $$<br>
# $$
# As(Z) = \frac{10}{18}
# $$

# %% [markdown]
# $$
# x_1 = \frac{\sigma_X^3}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^\frac{3}{2}} = \frac{\sqrt{46}}{2116} \approx 0,00320526
# $$<br>
# $$
# y_1 = \frac{\sigma_Y^3}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^\frac{3}{2}} = \frac{27\cdot\sqrt{46}}{2116} \approx 0,086542
# $$<br>
# $$
# z_1 = \frac{\sigma_Z^3}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^\frac{3}{2}} = \frac{54\cdot \sqrt{46}}{529} \approx  0,692336
# $$

# %% [markdown]
# $$
# As(S) = \frac{\sqrt{46}}{2116} \cdot \frac{10}{3} + \frac{27\cdot\sqrt{46}}{2116}\cdot\frac{10}{9}+\frac{54\cdot \sqrt{46}}{529}\cdot\frac{10}{18} = \frac{5\cdot\sqrt{46}}{69} \approx 0,491473
# $$

# %% [markdown]
# $$
# 4.2)\\
# $$
# $$
# As(S)  = \frac{1}{\sigma_S} =\frac{1}{0,3\cdot\sqrt{46}} \approx 0,491473
# $$

# %% [markdown]
# >$$Ex(X) = \frac{1}{\lambda_X} $$

# %% [markdown]
# $$5.1)\\
# Ex(S) = x_2 \cdot Ex(X) + y_2 \cdot Ex(Y) +z_2\cdot Ex(Z)\\
# $$

# %% [markdown]
# $$
# Ex(X) = \frac{100}{9}
# $$<br>
# $$
# Ex(Y) = \frac{100}{81}\\
# $$<br>
# $$
# Ex(Z) = \frac{100}{324}
# $$

# %% [markdown]
# $$
# x_2 = \frac{\sigma_X^4}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^2} = \frac{1}{2116}
# $$<br>
# $$
# y_2 = \frac{\sigma_Y^4}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^2} = \frac{81}{2116}
# $$<br>
# $$
# z_2 = \frac{\sigma_Z^4}{|\sigma_X^2+\sigma_Y^2+\sigma_Z^2|^2} = \frac{324}{529}
# $$

# %% [markdown]
# $$
# Ex(S) = \frac{50}{207} \approx 0,\overline{2415458937198067632850}
# $$

# %% [markdown]
# $$
# 5.2)\\
# Ex(S) = \frac{1}{\lambda_S} = \frac{1}{4,14} = \frac{50}{207} \approx 0,\overline{2415458937198067632850}
# $$

# %% [markdown]
# # 8.11

# %% [markdown]
# $$
# X = X_1 + X_2 + X_3 + X_4 + X_5 + X_6
# $$

# %% [markdown]
# $$
# X_k ∼ Geom(p_k = \frac{7-k}{6})\\
# k=\overline{1,6}
# $$

# %% [markdown]
# $$
# \mathbb{E}(X_k) = \frac{1}{p_k}=\frac{6}{7-k}
#
# $$

# %% [markdown]
# $$
# \mathbb{E}(X) = \sum_{k=1}^{6} \mathbb{E}(X_k) = 6\cdot\sum_{k=1}^{6} \frac{1}{k} = 14,7
# $$

# %% [markdown]
# $$
# \mathbb{V}ar(X) = \sum_{k=1}^{6} \mathbb{V}ar(X_k) = \sum_{k=1}^{5} \frac{\frac{k}{6}}{\big(\frac{6-k}{6}\big)^2} = \sum_{k=1}^{5} \frac{6\cdot k}{(6-k)^2} = 38,99
# $$

# %% [markdown]
# # 8.12

# %% [markdown]
# E(X) = 1/a +1/b + 1/c -(1/(a+b) + 1/(a+c) + 1/(c+b)) + 1/(a+b+c)
